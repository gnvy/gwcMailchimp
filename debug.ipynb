# %%
import pandas as pd

# %%
debug_file_path = 'aggregate_open/fall23_4.csv'
debug_data = pd.read_csv(debug_file_path)
debug_data.head(10)
# Out:
#                BU Email First Name   Last Name  Class Year  Address  \
# 0       yashikac@bu.edu        NaN         NaN         NaN      NaN
# 1        aryaxrp@bu.edu       Arya       Patel         NaN      NaN
# 2           yubo@bu.edu       Yubo         Qiu         NaN      NaN
# 3          eshav@bu.edu        NaN         NaN         NaN      NaN
# 4         lhakim@bu.edu     Lilyan       Hakim         NaN      NaN
# 5  airi.h0319@gmail.com       Airi      Hatori         NaN      NaN
# 6       mmarchio@bu.edu    Madison  Marchionna         NaN      NaN
# 7         sstang@bu.edu     Sophia        Tang         NaN      NaN
# 8        aaliang@bu.edu      Annie       Liang         NaN      NaN
# 9         ecinaj@bu.edu     Janice         Ang         NaN      NaN
#
#    Phone Number  Member Rating  Opens
# 0           NaN              2      2
# 1           NaN              2      1
# 2           NaN              2      2
# 3           NaN              2      1
# ...

# %%
print(debug_data.dtypes)
# Out:
# BU Email          object
# First Name        object
# Last Name         object
# Class Year       float64
# Address          float64
# Phone Number     float64
# Member Rating      int64
# Opens              int64
# dtype: object
